# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Шаг-1.-Загрузка-данных-и-подготовка-их-к-анализу" data-toc-modified-id="Шаг-1.-Загрузка-данных-и-подготовка-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Шаг 1. Загрузка данных и подготовка их к анализу</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Шаг-2.--Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Шаг-2.--Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Шаг 2.  Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-для-расчёта-LTV-и-ROI" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI</a></span></li><li><span><a href="#Функция-для-расчёта-удержания" data-toc-modified-id="Функция-для-расчёта-удержания-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция для расчёта удержания</a></span></li><li><span><a href="#Функция-для-расчёта-конверсии" data-toc-modified-id="Функция-для-расчёта-конверсии-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для расчёта конверсии</a></span></li><li><span><a href="#Функция-для-сглаживания-фрейма" data-toc-modified-id="Функция-для-сглаживания-фрейма-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция для сглаживания фрейма</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии" data-toc-modified-id="Функция-для-визуализации-конверсии-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция для визуализации конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li></ul></li><li><span><a href="#Шаг-3.-Проведение-исследовательского-анализа-данных" data-toc-modified-id="Шаг-3.-Проведение-исследовательского-анализа-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Шаг 3. Проведение исследовательского анализа данных</a></span><ul class="toc-item"><li><span><a href="#Построение-профилей-пользователей.-Определение-минимальной-и-максимальной-даты-привлечения-пользователей." data-toc-modified-id="Построение-профилей-пользователей.-Определение-минимальной-и-максимальной-даты-привлечения-пользователей.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Построение профилей пользователей. Определение минимальной и максимальной даты привлечения пользователей.</a></span></li><li><span><a href="#Из-каких-стран-приходят-посетители?-Какие-страны-дают-больше-всего-платящих-пользователей?" data-toc-modified-id="Из-каких-стран-приходят-посетители?-Какие-страны-дают-больше-всего-платящих-пользователей?-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?</a></span></li><li><span><a href="#По-каким-рекламным-каналам-шло-привлечение-пользователей?-Какие-каналы-приносят-больше-всего-платящих-пользователей?" data-toc-modified-id="По-каким-рекламным-каналам-шло-привлечение-пользователей?-Какие-каналы-приносят-больше-всего-платящих-пользователей?-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Шаг-4.-Маркетинг" data-toc-modified-id="Шаг-4.-Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Шаг 4. Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Расходы-на-маркетинг." data-toc-modified-id="Расходы-на-маркетинг.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Расходы на маркетинг.</a></span></li><li><span><a href="#Cтоимость-привлечения-одного-пользователя" data-toc-modified-id="Cтоимость-привлечения-одного-пользователя-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Cтоимость привлечения одного пользователя</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Шаг-5.-Оценка-окупаемости-рекламы-для-привлечения-пользователей" data-toc-modified-id="Шаг-5.-Оценка-окупаемости-рекламы-для-привлечения-пользователей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Шаг 5. Оценка окупаемости рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-окупаемости-рекламы." data-toc-modified-id="Анализ-общей-окупаемости-рекламы.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Анализ общей окупаемости рекламы.</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Шаг-6.--Выводы-исследования" data-toc-modified-id="Шаг-6.--Выводы-исследования-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Шаг 6.  Выводы исследования</a></span></li></ul></div>

# %% [markdown]
# # Анализ бизнес-показателей приложения

# %% [markdown]
# ## Шаг 1. Загрузка данных и подготовка их к анализу

# %%
import warnings
warnings.filterwarnings('ignore')#скрытие предупреждений

import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import seaborn as sns

# %%
visits = pd.read_csv('/datasets/visits_info_short.csv') # журнал сессий
orders = pd.read_csv('/datasets/orders_info_short.csv') # покупки
costs = pd.read_csv('/datasets/costs_info_short.csv') # траты на рекламу

display(visits.head())
display(orders.head())
display(costs.head())
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# ...

# %%
# Получение общей информации о данных в таблицах
visits.info() 
orders.info()
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
# User Id          309901 non-null int64
# Region           309901 non-null object
# Device           309901 non-null object
# Channel          309901 non-null object
# Session Start    309901 non-null object
# Session End      309901 non-null object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
# User Id     40212 non-null int64
# Event Dt    40212 non-null object
# Revenue     40212 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
# dt         1800 non-null object
# Channel    1800 non-null object
# costs      1800 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Пропусков нет. Приведу названия к едтиному стилю, изменю типы данных и проверю наличие дубликатов.

# %%
#Приведу названия столбцов к нижнему регистру и заменю пробелы на "_" в visits и orders

costs.columns = costs.columns.str.lower()
visits.columns = [x.lower().replace(' ', '_') for x in visits.columns.values]
orders.columns = [x.lower().replace(' ', '_') for x in orders.columns.values]


#Изменю типы данных для столбцов с датами
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date 

#Подсчёт явных дубликатов в таблицах
print ('Явных дубликатов в таблице visits:', visits.duplicated().sum())
print ('Явных дубликатов в таблице orders:', orders.duplicated().sum())
print ('Явных дубликатов в таблице costs:', costs.duplicated().sum())
# Out:
# Явных дубликатов в таблице visits: 0
# Явных дубликатов в таблице orders: 0
# Явных дубликатов в таблице costs: 0

# %%
#Проверю изменения

visits.info() 
orders.info()
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
# user_id          309901 non-null int64
# region           309901 non-null object
# device           309901 non-null object
# channel          309901 non-null object
# session_start    309901 non-null datetime64[ns]
# session_end      309901 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
# user_id     40212 non-null int64
# event_dt    40212 non-null datetime64[ns]
# revenue     40212 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
# dt         1800 non-null object
# channel    1800 non-null object
# costs      1800 non-null float64
# ...

# %% [markdown]
# ### Вывод
#
# Была проведена предобработка данных:
# - Названия столбцов были приведены к единому стилю;
# - Проведена замена типов данных;
# - Проведена проверка на пропуски и дубликаты.

# %% [markdown]
# ## Шаг 2.  Функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# Задам функции для расчета LTV, ROI, удержания, конверсии а также их визуализации.

# %% [markdown]
# ### Функция для расчёта LTV и ROI

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        orders[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для расчёта удержания

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    visits,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
       visits[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта конверсии

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        orders.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Задам функции для визуализации этих метрик — filter_data(), plot_retention(), plot_conversion() и plot_ltv_roi()

# %% [markdown]
# ### Функция для сглаживания фрейма

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для визуализации удержания

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации конверсии

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Шаг 3. Проведение исследовательского анализа данных
#
# Построение профилей пользователей. Определение минимальной и максимальной даты привлечения пользователей.
#
# Выяснить:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %% [markdown]
# ### Построение профилей пользователей. Определение минимальной и максимальной даты привлечения пользователей.

# %% [markdown]
# Для дальнейшего анализа составлю профили клиентов - таблицу с деталями первого посещения каждого пользователя, такими как источник перехода на сайт, устройство, страна.

# %%
# Функция для построения клиентских профилей
def get_profiles(visits, orders):
    # сортирую сессии по ID пользователя и дате посещения
    # группирую по ID 
    # нахожу первые значения session_start, channel, device, region
    # столбец с временем первого посещения назову first_ts (first timestamp — первая временная отметка)

    profiles = (
        visits.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device' : 'first', 
                'region' : 'first', 
               
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # определяю дату первого посещения
    # и первый день месяца, в который это посещение произошло
    # эти данные понадобятся для когортного анализа
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
    
     # проверю, есть ли ID пользователей из profiles в orders
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    return profiles

# %%
# получаем профили пользователей
profiles = get_profiles(visits, orders)
display(profiles)
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %% [markdown]
# Получилась таблица профилей, в каждом из которых есть данные о дате первого посещения, рекламном источнике, устройстве и стране пользователей.
# Имея готовые профили пользователей, можно быстро посчитать общее количество  и долю платящих пользователей в разбвке по странам, устройству и источнику.

# %%
#Определю минимальную и максимальную даты привлечения пользователей
print('Минимальная дата привлечения пользователей:', profiles['dt'].min())
print('Максимальная дата привлечения пользователей:', profiles['dt'].max())
# Out:
# Минимальная дата привлечения пользователей: 2019-05-01
# Максимальная дата привлечения пользователей: 2019-10-27

# %%
#Напишу функцию для создания сводных таблиц 
def pivot(groupby):
    pivot = profiles.groupby(groupby).agg({'user_id': 'nunique', 'payer':'mean'})
    pivot.columns = ['кол-во пользователей', 'доля платящих']
    pivot = pivot.sort_values(by = 'кол-во пользователей', ascending = False)

    return pivot

# %%
#Напишу функцию для создания графиков
def pivot_plot(table):
    plt.figure(figsize=(10,7))
    plt.subplot(2,2,1)
    table['кол-во пользователей'].sort_values(ascending = False).head().plot(kind='bar', grid=True, rot=45, color= 'tab:blue', width=0.3)
    plt.title('кол-во пользователей')
    plt.subplot(2,2,2)
    table['доля платящих'].sort_values(ascending = False).head().plot(kind='bar', grid=True, rot=45, color= 'tab:orange', width=0.3)
    plt.title('доля платящих пользователей')
    plt.show()

# %% [markdown]
# ### Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?

# %%
#количество пользователей и доля платящих пользователей в разбивке по странам
region_pivot = pivot('region')
display(region_pivot)

pivot_plot(region_pivot)
# Out:
#                кол-во пользователей  доля платящих
# region
# United States                100002       0.069019
# UK                            17575       0.039829
# France                        17450       0.037994
# Germany                       14981       0.041119

# %% [markdown]
# Пользователи приложения Procrastinate Pro+ из США, Германии, Великобритании и Франции. Больше всего платящих пользователей приходит из США, почти 7%. Доля платящих пользователей в остальных странах составляет порядка 4%.

# %% [markdown]
# **Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?**

# %%
#количество пользователей и доля платящих пользователей в разбивке по устройствам
#device_pivot = pivot('device').style.format("{:.2f}") #при запуске пропадают графики
device_pivot = pivot('device')
display(device_pivot)

pivot_plot(device_pivot)
# Out:
#          кол-во пользователей  доля платящих
# device
# iPhone                  54479       0.062079
# Android                 35032       0.058518
# PC                      30455       0.050468
# Mac                     30042       0.063644

# %% [markdown]
# Пользователи активнее используют мобильные устройства. Среди пользоватлей продукции Apple самая высокая доля платящих клиентов, причем выше всего показатель по стационарным Mac.  Iphone и Android  имеют похожие показатели - около 6%. PC- 5%.

# %% [markdown]
# ### По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %%
#количество пользователей и доля платящих пользователей в разбивке по источникам
channel_pivot = pivot('channel')
display(channel_pivot)

pivot_plot(channel_pivot)
# Out:
#                     кол-во пользователей  доля платящих
# channel
# organic                            56439       0.020553
# FaceBoom                           29144       0.122049
# TipTop                             19561       0.096007
# OppleCreativeMedia                  8605       0.027077
# LeapBob                             8553       0.030633
# WahooNetBanner                      8553       0.052964
# RocketSuperAds                      4448       0.079137
# MediaTornado                        4364       0.035747
# YRabbit                             4312       0.038265
# AdNonSense                          3880       0.113402
# lambdaMediaAds                      2149       0.104700

# %% [markdown]
# Большинство пользователей пришли в приложение самостоятельно (органические пользователи), однако доля платящих из них не высока, всего 2%. Привлечение шло по 10 рекламным каналам. В количественном отношении больше всего пользователей было привлечено из каналов FaceBoom и TipTop, также по ним высокие доли платящих клиентов- 12% и 9.6% соответсвенно. Стоит обратить внимание на каналы AdNonSense, lambdaMediaAds, RocketSuperAds, имеющие высокую долю платящих клиентов (11%, 10%, 7.9%) при невысоком общем количестве привлеченных пользователей.

# %% [markdown]
# ### Вывод
#
# При проведении исследовательского анализа было выявлено:
#
# 1. Минимальная дата привлечения пользователей: 2019-05-01;
#    Максимальная дата привлечения пользователей: 2019-10-27.
#
# 2. Пользователи приложения Procrastinate Pro+ из США, Германии, Великобритании и Франции. Больше всего платящих пользователей приходит из США, почти 7%. Доля платящих пользователей в остальных странах составляет порядка 4%.
#
# 3. Пользователи активнее используют мобильные устройства. Среди пользоватлей продукции Apple самая высокая доля платящих клиентов, причем выше всего показатель по стационарным Mac. Iphone и Android имеют похожие показатели - около 6%. PC- 5%.
#
# 4. Большинство пользователей пришли в приложение самостоятельно (органические пользователи), однако доля платящих из них не высока, всего 2%. Привлечение шло по 10 рекламным каналам. В количественном отношении больше всего пользователей было привлечено из каналов FaceBoom и TipTop, также по ним высокие доли платящих клиентов- 12% и 9.6% соответсвенно. Стоит обратить внимание на каналы AdNonSense, lambdaMediaAds, RocketSuperAds, имеющие высокую долю платящих клиентов (11%, 10%, 7.9%) при невысоком общем количестве привлеченных пользователей.

# %% [markdown]
# ## Шаг 4. Маркетинг
#
# Выяснить:
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %% [markdown]
# ### Расходы на маркетинг.

# %% [markdown]
# Посчитаю общую сумму расходов на маркетинг и их посмотрю на распределение затрат по источникам. Для визуализации расходов построю диаграмму динамики расходов в разбивке по каналам по дням.

# %%
marketing_costs = sum(costs['costs'])

# %%
#Посчитаю общую сумму расходов на маркетинг и их распределение по источникам. 
print('Сумарные расходы на маркетинг:', '{:.0f}'.format(marketing_costs))
display(costs.groupby('channel').agg({'costs':'sum'}).sort_values(by='costs', ascending = False).style.format("{:.0f}"))
# Out:
# Сумарные расходы на маркетинг: 105497
# <style  type="text/css" >
# </style><table id="T_3f0490f2_a483_11ec_956e_02420a3923ff" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >costs</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3f0490f2_a483_11ec_956e_02420a3923fflevel0_row0" class="row_heading level0 row0" >TipTop</th>
#                         <td id="T_3f0490f2_a483_11ec_956e_02420a3923ffrow0_col0" class="data row0 col0" >54751</td>
#             </tr>
#             <tr>
#                         <th id="T_3f0490f2_a483_11ec_956e_02420a3923fflevel0_row1" class="row_heading level0 row1" >FaceBoom</th>
#                         <td id="T_3f0490f2_a483_11ec_956e_02420a3923ffrow1_col0" class="data row1 col0" >32446</td>
#             </tr>
#             <tr>
# ...

# %%
#выделю 5 каналов с самыми высокими затратами, чтобы не загрязнять график.
top_costs_channel=['TipTop', 'FaceBoom', 'WahooNetBanner', 'AdNonSense','OppleCreativeMedia']

# %%
#Строю диаграмму динамики расходов в разбивке по каналам по дням.
costs.query('channel in @top_costs_channel').pivot_table(
    index='dt',  # дата проведения рекламной кампании
    columns='channel', # рекламный источник
    values='costs',  # расходы на рекламную кампанию
    aggfunc='sum',  
).plot(figsize=(15, 5), grid=True)

plt.show()

# %% [markdown]
# **Итак**, общие расходы на маркетинг составили 105497 у.е. за весь период.
#
# Затраты на маркетинг первые две недели мая не привышали 150 у.е. и распределялись по каналам достаточно равномерно: около 100-130 у.е. на FaceBoom, порядка 50-80у.е. на TipTop, около 50у.е. на  AdNonSense и небольшие, околонулевые траты на WahooNetBanner и OppleCreativeMedia. Но уже во второй половине мая заметно, что ставка делается на два основных канала - FaceBoom и TipTop.  В июне затраты на эти каналы приблизительно равны, а к июлю видно увеличение вложений в рекламу на TipTop. Маркетинговые затраты на TipTop становятся приблизительно в два раза выше, чем на FaceBoom. И эта тенденция сохраняется на протяжении всего периода. Самыми дорогими оказались рекламные кампании, проведенные в сентябре - октябре. Затраты на TipTop достигали значений выше 600у.е, на FaceBoom 300 у.е.
# Затраты на остальные каналы уже к июню сокращаются и держатся на одном уровне около 30-50 у.е. на протяжении всего периода.

# %% [markdown]
# ### Cтоимость привлечения одного пользователя

# %% [markdown]
# **Далее изучу, сколько в среднем стоило привлечение одного пользователя из каждого источника.**
# Для этого посчитаю метрику CAC (Customer Acquisition Cost) — стоимость привлечение каждого нового клиента.
#
# Рассчитаю средний CAC на одного пользователя для всего проекта и для каждого источника трафика. Буду использовать полученные профили пользователей.

# %% [markdown]
# Дополню функцию для создания пользовательских профилей get_profiles(), введу параметр ad_costs, посчитаю количество привлечённых пользователей для каждой даты и источника и сопоставлю данные.

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, events, ad_costs, event_names=[]):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # добавляем флаги для всех событий из event_names
    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique()
            )

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    #исключаю органических пользователей из profiles
    profiles = profiles.query('channel != "organic"')
    
    # стоимость привлечения органических пользователей равна нулю
    #profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# Так как органические пользователи приходят в приложение самостоятельно, и компания не несет затрат на их привличение -  для дальнейшего анализа исключила их из портретов пользователей (в теле функции).

# %%
#Вызываю обновленую функцию, с расчетом CAC (acquisition_cost) на каждого привлеченного клиента
profiles = get_profiles(visits, orders, None, costs)
display(profiles.head(5))
# Out:
#     user_id            first_ts     channel   device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom      Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom   iPhone  United States
# 3  22593348 2019-08-22 21:35:48  AdNonSense       PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit   iPhone  United States
# 7  46006712 2019-06-30 03:46:29  AdNonSense  Android         France
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769
# 7  2019-06-30 2019-06-01   True          1.008000

# %%
#Расчитаю средний CAC на одного пользователя для всего проекта (без разбивки по каналам):
CAC_general = marketing_costs / profiles['user_id'].count()

print(f'Cредний CAC на одного пользователя для всего проекта составляет: {CAC_general:.2f} у.е.')
# Out:
# Cредний CAC на одного пользователя для всего проекта составляет: 1.13 у.е.

# %%
# строю график истории изменений CAC по каналам привлечения

profiles.pivot_table(
    index='dt',  # дата проведения рекламной кампании
    columns='channel', # рекламный источник
    values='acquisition_cost',  # стоимость привлечения пользователей
    aggfunc='mean',  
).plot(figsize=(15, 5), grid=True)
plt.ylabel('CAC, у.е')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')

plt.show()

# %% [markdown]
# Стоимость привлечения одного клиента через канал TipTop растет каждый месяц, кроме октября. Произошло увеличение показателя CAC  в 3,5 раза за 4 месяца.  CAC по остальным каналам достаточно стабилен.

# %% [markdown]
# ### Вывод:
#
# - Общие расходы на маркетинг составили 105497 у.е.
# - Ставка делается на два основных канала - FaceBoom и TipTop.  В июне затраты на эти каналы приблизительно равны, а к июлю видно увеличение вложений в рекламу на TipTop. Маркетинговые затраты на TipTop становятся приблизительно в два раза выше, чем на FaceBoom. И эта тенденция сохраняется на протяжении всего периода. Самыми дорогими оказались рекламные кампании, проведенные в сентябре - октябре. Затраты на TipTop достигали значений выше 600у.е, на FaceBoom 300 у.е.
# - Затраты на остальные каналы с июня держатся на одном уровне около 30-50 у.е. на протяжении всего периода.
#
# - Cредний CAC на одного пользователя для всего проекта составляет: 1.13 у.е.
# - CAC в разбивке по каналам достаточно стабилен, за исключением канала TipTop. Стоимость привлечения одного клиента через TipTop растет каждый месяц, кроме октября. Произошло увеличение показателя CAC в 3,5 раза за 4 месяца (до 3.5 у.е.)

# %% [markdown]
# ## Шаг 5. Оценка окупаемости рекламы для привлечения пользователей
#
# С помощью LTV и ROI:
# - Проанализировать общую окупаемость рекламы;
# - Проанализировать окупаемость рекламы с разбивкой по устройствам;
# - Проанализировать окупаемость рекламы с разбивкой по странам;
# - Проанализировать окупаемость рекламы с разбивкой по рекламным каналам.
#
# Описать проблемы, которые были обнаружены. Ответить на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучить конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Описать возможные причины обнаруженных проблем и сформировать рекомендации для рекламного отдела.
# Данные  на 1-е ноября 2019 года, в  организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.

# %% [markdown]
# ### Анализ общей окупаемости рекламы.
# Построение графиков LTV и ROI, а также графиков динамики LTV, CAC и ROI.

# %%
#Задам момент и горизонт анализа
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# **По графикам можно сделать такие выводы:**
# - Инвестици в рекламу не окупаются даже к концу лайфтайма.
# - По графику динамики ROI  на 14 день, видно, что реклама окупалась только в начале рассматриваемого периода, в июле ROI на 14 день принимает пограничные значения, а далее начинает падать ниже уровня окупаемости.
# - CAC растет, т.е. заметно увеличился рекламный бюджет.
# - LTV достаточно стабилен. Значит, дело не в ухудшении качества пользователей.
#
# Для полной картины пройду по всем доступным характеристикам пользователей — стране, источнику и устройству первого посещения.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %% [markdown]
# Для анализа окупаемости рекламы с разбивкой по устройствам - передам параметру dimensions столбец device.

# %%
# окупаемость с разбивкой по устройствам

dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# - По общему графику ROI преодолевают границу уровня окупаемости только пользователи PC, но при этом по PC самая низкая "пожизненная ценность" клиента (т.е. пользователи PC приносят меньше всего денег компании).
# - Наблюдается обратная зависимость между показателями CAC и графиком ROI. Самые высокие затраты на рекламу для Iphone и Mac, а неокупаются эти устройства сильнее всего. Затраты на Android ниже, и на графике ROI видно, что Android ближе всего к порогу окупаемости (из аутсайдеров).
# - По графику динамики ROI  на 14 день, видно, что с сентября реклама не окупаестя вообще, даже для устройства PC, по которому наблюдалась достаточно высокая окупаемость.
# - LTV достаточно стабилен для всех устройств.

# %% [markdown]
# Посчитаю и визуализирую конверсию, вызвав функции get_conversion() и plot_conversion(). А также удержание, для расчета и визуализации которого вызову функции get_retention() и plot_retention().

# %%
# смотрю конверсию с разбивкой по устройствам

dimensions = ['device']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Пользователи PC конвертируются хуже всего, Iphone и Mac- лучше всего, причем на протяжении всего времени.

# %%
# смотрю удержание с разбивкой по устройствам

dimensions = ['device']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Ожидаемо, удержание платящих пользоватлей выше, чем неплатящих. Но в целом с удержанием по всем устройствам все впорядке.

# %% [markdown]
# **Вывод:**
# - С сентября реклама не окупаестя вообще, даже для устройства PC, по которому наблюдалась достаточно высокая окупаемость.
# - По общему графику ROI преодолевают границу уровня окупаемости только пользователи PC, но при этом по PC самая низкая "пожизненная ценность" клиента (т.е. пользователи PC приносят меньше всего денег компании).
# - Самые высокие затраты на рекламу для Iphone и Mac, при неокупаются эти устройства сильнее всего. Затраты на Android ниже, и на графике ROI видно, что Android ближе всего к порогу окупаемости (из аутсайдеров).
# - LTV достаточно стабилен для всех устройств.
# - Пользователи PC конвертируются хуже всего, Iphone и Mac- лучше всего, причем на протяжении всего времени.
# - С удержанием по всем устройствам все впорядке.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам

# %% [markdown]
# Для анализа окупаемости рекламы с разбивкой по странам - передам параметру dimensions столбец region.

# %%
# окупаемость с разбивкой по странам

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Разбивка по странм выдает интересную картину:
#
# - Стоимость привлечения стабильна для всех стран, кроме США. В США стоимость привлечения быстро растет и в октебере уже в 5 раз выше стоимости проивлечения в других странах.
# - LTV по США достаточно стабилен и немного выше, чем в остальных странах, т.е. общая сумма денег, которую один клиент США в среднем приносит компании со всех своих покупок выше. По Великобритании LTV неочень стабилен, но в некоторые периоды достигает даже показателей по США.
# - Реклама окупается во всех странах, кроме США. Лучше всего окупаются Великобритания.
# - В динамике показатель ROI по США стабильно падает.
#
# Получается, что самые ценные клиенты в денежном выражении - пользователи из США, однако по ним неисоизмеримо высокая стоимость привлечения и соответсвенно траты на рекламу по США не окупаются.

# %%
# смотрю конверсию с разбивкой по устройствам

dimensions = ['region']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# По графикам конверсии действительно заметна разница в конвертируемости пользователей США по сравнению с другими странами. Т.е. пользователи из США чаще переходят в "плятящие".

# %%
# смотрю удержание с разбивкой по устройствам

dimensions = ['region']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Но вот удежание среди платящих пользователей из США ниже чем в остальных странах, в т.ч. в динамике.

# %% [markdown]
# **Вывод:**
#
# - Стоимость привлечения стабильна для всех стран, кроме США. В США стоимость привлечения быстро растет и в октебере уже в 5 раз выше стоимости проивлечения в других странах.
# - LTV по США достаточно стабилен и немного выше, чем в остальных странах, т.е. общая сумма денег, которую один клиент США в среднем приносит компании со всех своих покупок выше. По Великобритании LTV неочень стабилен, но в некоторые периоды достигает даже показателей по США.
# - Реклама окупается во всех странах, кроме США. Лучше всего окупаются Великобритания.
# - В динамике показатель ROI по США стабильно падает.
#
# - Получается, что самые ценные клиенты в денежном выражении - пользователи из США, однако по ним неисоизмеримо высокаястоимость привлечения и соответсвенно траты на рекламу по США не окупаются.
#
# - По графикам конверсии действительно заметна разница в конвертируемости пользователей США по сравнению с другими странами. Т.е. пользователи из США чаще переходят в "плятящие".
# - Но вот удежание среди платящих пользователей из США ниже чем в остальных странах, в т.ч. в динамике.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %% [markdown]
# Для анализа окупаемости рекламы с разбивкой по каналам - передам параметру dimensions столбец channel.

# %%
# окупаемость с разбивкой по источникам привлечения

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# - Реклама по каналам привлечения TipTop, FaceBoom и AdNonSense не окупается. В динамике картина схожа - TipTop, FaceBoom не окупаются вообще, AdNonSense иногда пересекает порог окупаемости.
# - окупаемость канала YRabbit нестабильна, в июле она достигала пиковых значений, а в октябре заметно падение. В целом все каналы стабильно окупаются. Отдельно стоит выделить канал LambdaMediaAds, имеющий стабильный уровень окупаемости, среднюю стоиомсть привлечения и  высокий самый показатель Lifetime Value. Средне-стабильные показатели ROI и LTV имеют WahooNetBanner и RocketSuperAds при умереной стоиомости привлечения.

# %%
# смотрю конверсию с разбивкой по устройствам

dimensions = ['channel']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# - FaceBoom и AdNonSense имеют самые высокие показатели конверсии.
# - LambdaMediaAds относительно других "недорогих" каналов имеет высокую конверсию. WahooNetBanner и RocketSuperAds тоже конвертируются хорошо.

# %%
# смотрю удержание с разбивкой по устройствам

dimensions = ['channel']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Пользователи привлеченные по каналам FaceBoom и AdNonSense стабильно плохо удерживаются, приблизительно в 2,5 раза хуже остальных.

# %% [markdown]
# **Вывод:**
# -  Реклама по каналам привлечения TipTop, FaceBoom и AdNonSense не окупается, кроме того пользователи привлеченные по каналам FaceBoom и AdNonSense стабильно плохо удерживаются, приблизительно в 2,5 раза хуже остальных.
#
# - В целом все остальные каналы стабильно окупаются, кроме канала YRabbit (окупаемость по которому в июле достигала пиковых значений, а в октябре заметно упала).
#
# - Стоит выделить канал LambdaMediaAds, имеющий стабильный уровень окупаемости, среднюю стоиомсть привлечения и  высокий самый показатель Lifetime Value. При этом имеет достаточно высокий уровень конверсии и удержания.
#
# - Средне-стабильные показатели ROI и LTV имеют WahooNetBanner и RocketSuperAds при умереной стоиомости привлечения. Пользователи из этих каналов достаочно хорошо конвертируются и удерживаются.

# %% [markdown]
# ### Вывод
#
# 1. В целом реклама не окупается. Инвестиции в рекламу окупались только в начале рассматриваемого периода, начиная с июля показатель ROI опускается ниже уровня окупаемости. При этом от месяца к месяцу заметно увеличивается рекламный бюджет. Общий LTV достаточно стабилен. Значит, дело не в ухудшении качества пользователей.
#
#
# 2. Снижение окупаемости врядли можно связать с типом устройства. Затраты на рекламу для PC ниже всего, но пользователи PC конвертируются в "платящих" хуже всего. Для  Iphone и Mac затраты на рекламу высоки, но пользователи имеют высокий уровень конверсии. Пользователи Android также не окупаются, но близки к порогу окупаемости, при этом имеют стабильные показатели конверсии и удержания.
#
#
# 3. На снижание окупаемости влияет стоимость привлечения клиентов из США, которая стремительно растет и в октябре привышает стоимость привлечения в других странах почти в 5 раз. При этом LTV по США достаточно стабилен и немного выше, чем в остальных странах, т.е. общая сумма денег, которую один клиент США в среднем приносит компании со всех своих покупок выше. Пользователи из США лучше других конвертируются, но имеют низкие показатели удержания, в т.ч. в динамике. Для других стран стоимость привлечения стабильна. Реклама окупается везде, кроме США (лучше всего окупаются Великобритания). С конверсией и удержанием по другим странам тоже все стабильно.
#
#
# 4. На окупаемость также влияют и рекламные каналы. Реклама по каналам привлечения TipTop, FaceBoom и AdNonSense не окупается, кроме того пользователи привлеченные по каналам FaceBoom и AdNonSense стабильно плохо удерживаются, приблизительно в 2,5 раза хуже остальных.
#
#
# **Рекламному отделу следует** изменить каналы привлечения пользоватлей. Стоимость рекламы на топовых площадках слишком велика и не дает желаемого результата. Обратить внимание на каналы:
#         - LambdaMediaAds, имеющий стабильный уровень окупаемости, среднюю стоиомсть привлечения и  высокий самый показатель Lifetime Value. При этом имеет достаточно высокий уровень конверсии и удержания.
#         - Средне-стабильные показатели ROI и LTV имеют WahooNetBanner и RocketSuperAds при умереной стоиомости привлечения. Пользователи из этих каналов достаочно хорошо конвертируются и удерживаются.
#
# Для снижения стоимости  и увеличения удержания следует изменить способ привлечения пользователей из США. При этом важно удежрать этот рынок, так как это пользователи наиболее платежеспособны.

# %% [markdown]
# ## Шаг 6.  Выводы исследования
# - Выделить причины неэффективности привлечения пользователей;
# - Сформировать рекомендации для отдела маркетинга для повышения эффективности.

# %% [markdown]
# Данное исследование было проведено для развлекательного приложения Procrastinate Pro+.
# Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки. Были разобраны возможные причины и сделаны следующие выводы:
# 1. Пользователи:
#     1.1 Пользователи приложения Procrastinate Pro+ из США, Германии, Великобритании и Франции. Больше всего платящих пользователей приходит из США, почти 7%. Доля платящих пользователей в остальных странах составляет порядка 4%.
#
#     1.2 Пользователи активнее используют мобильные устройства. Среди пользоватлей продукции Apple самая высокая доля платящих клиентов, причем выше всего показатель по стационарным Mac. Iphone и Android имеют похожие показатели - около 6%. PC- 5%.
#
#     1.3. Большинство пользователей пришли в приложение самостоятельно (органические пользователи), однако доля платящих из них не высока, всего 2%. Привлечение шло по 10 рекламным каналам. В количественном отношении больше всего пользователей было привлечено из каналов FaceBoom и TipTop, также по ним высокие доли платящих клиентов- 12% и 9.6% соответсвенно. lambdaMediaAds, RocketSuperAds, имеют высокую долю платящих клиентов (10%, 7.9%) при невысоком общем количестве привлеченных пользователей.
#
#
# 2. Ситуация с маркетингом сейчас:
#
#     2.1 Общие расходы на маркетинг составили 105497 у.е.
#
#     2.2 Ставка делается на два основных канала - FaceBoom и TipTop. В июне затраты на эти каналы приблизительно равны, а к июлю видно увеличение вложений в рекламу на TipTop. Маркетинговые затраты на TipTop становятся приблизительно в два раза выше, чем на FaceBoom. И эта тенденция сохраняется на протяжении всего периода. Самыми дорогими оказались рекламные кампании, проведенные в сентябре - октябре. Затраты на TipTop достигали значений выше 600у.е, на FaceBoom 300 у.е.
#
#     2.3 Затраты на остальные каналы с июня держатся на одном уровне около 30-50 у.е. на протяжении всего периода.
#
#     2.4. Cредний стоимость привлечения одного клиента для всего проекта составляет: 1.13 у.е.
#
#     2.5 CAC в разбивке по каналам достаточно стабилен, за исключением канала TipTop. Стоимость привлечения одного клиента через TipTop растет каждый месяц, кроме октября. Произошло увеличение показателя CAC в 3,5 раза за 4 месяца (до 3.5 у.е.)
#
#
# 3. Анализ окупаемости рекламы показал:
#
#     3.1 В целом реклама не окупается. Инвестиции в рекламу окупались только в начале рассматриваемого периода, начиная с июля показатель ROI опускается ниже уровня окупаемости. При этом от месяца к месяцу заметно увеличивается рекламный бюджет. Общий LTV достаточно стабилен. Значит, дело не в ухудшении качества пользователей.
#
#     3.2 Снижение окупаемости врядли можно связать с типом устройства. Затраты на рекламу для PC ниже всего, но пользователи PC конвертируются в "платящих" хуже всего. Для  Iphone и Mac затраты на рекламу высоки, но пользователи имеют высокий уровень конверсии. Пользователи Android также не окупаются, но близки к порогу окупаемости, при этом имеют стабильные показатели конверсии и удержания.
#
#     3.3 На снижание окупаемости влияет стоимость привлечения клиентов из США, которая стремительно растет и в октябре привышает стоимость привлечения в других странах почти в 5 раз. При этом LTV по США достаточно стабилен и немного выше, чем в остальных странах, т.е. общая сумма денег, которую один клиент США в среднем приносит компании со всех своих покупок выше. Пользователи из США лучше других конвертируются, но имеют низкие показатели удержания, в т.ч. в динамике. Для других стран стоимость привлечения стабильна. Реклама окупается везде, кроме США (лучше всего окупаются Великобритания). С конверсией и удержанием по другим странам тоже все стабильно.
#
#     3.4 На окупаемость также влияют и рекламные каналы. Реклама по каналам привлечения TipTop, FaceBoom и AdNonSense не окупается, кроме того пользователи привлеченные по каналам FaceBoom и AdNonSense стабильно плохо удерживаются, приблизительно в 2,5 раза хуже остальных.
#
#
# 4. Рекомендации рекламному отделу:
#
#     4.1. Необходимо координально пересмотреть рекламную политику по привлечению пользователей из США. При этом важно удежрать этот рынок,т.к. там самая высокая доля платящих клиентов (7%) при высоком и стабильном LTV.
#
#     4.2. Отказаться от рекламы на FaceBoom и AdNonSense в связи с высокой стоимостью, отсутвием окупаемости и плохим удержанием.
#
#     4.3. Пользователи TipTop имеют устойчивый уровень удержания, но реклама на TipTop имеет самую высокую постоянно растущую стоимость. От него также следует отказаться.
#
#     4.4. Продолжать размещать рекламу по всем остальным каналм, но особенно обратить внимание и увеличить финансирование для следующих:
#         - LambdaMediaAds, имеющий стабильный уровень окупаемости, среднюю стоиомсть привлечения и  высокий самый показатель Lifetime Value. При этом имеет достаточно высокий уровень конверсии и удержания.
#         - Средне-стабильные показатели ROI и LTV имеют WahooNetBanner и RocketSuperAds при умереной стоиомости привлечения. Пользователи из этих каналов достаочно хорошо конвертируются и удерживаются.
#
#     4.5. Приоритетными устройстывами являются Android (стоимость рекламы ниже, хорший процент платящих пользователей (6%) и близость к границе окупаемости, стабильные показатели конверсии и удержания), затем  Mac, Iphone и PC.
